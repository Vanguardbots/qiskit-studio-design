# %%
# !pip install pyscf ffsim qiskit_addon_sqd joblib
# Out:
# Requirement already satisfied: pyscf in /Users/ismaelfaro/.env/pyai/lib/python3.12/site-packages (2.9.0)
# Requirement already satisfied: ffsim in /Users/ismaelfaro/.env/pyai/lib/python3.12/site-packages (0.0.57)
# Requirement already satisfied: qiskit_addon_sqd in /Users/ismaelfaro/.env/pyai/lib/python3.12/site-packages (0.11.0)
# Collecting joblib
#   Downloading joblib-1.5.1-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: numpy!=1.16,!=1.17,>=1.13 in /Users/ismaelfaro/.env/pyai/lib/python3.12/site-packages (from pyscf) (2.3.1)
# Requirement already satisfied: scipy>=1.6.0 in /Users/ismaelfaro/.env/pyai/lib/python3.12/site-packages (from pyscf) (1.16.0)
# Requirement already satisfied: h5py>=2.7 in /Users/ismaelfaro/.env/pyai/lib/python3.12/site-packages (from pyscf) (3.14.0)
# Requirement already satisfied: setuptools in /Users/ismaelfaro/.env/pyai/lib/python3.12/site-packages (from pyscf) (80.9.0)
# Requirement already satisfied: opt-einsum in /Users/ismaelfaro/.env/pyai/lib/python3.12/site-packages (from ffsim) (3.4.0)
# Requirement already satisfied: orjson in /Users/ismaelfaro/.env/pyai/lib/python3.12/site-packages (from ffsim) (3.10.18)
# Requirement already satisfied: qiskit>=1.3 in /Users/ismaelfaro/.env/pyai/lib/python3.12/site-packages (from ffsim) (2.1.0)
# Requirement already satisfied: typing-extensions in /Users/ismaelfaro/.env/pyai/lib/python3.12/site-packages (from ffsim) (4.14.0)
# Requirement already satisfied: jax>=0.4.30 in /Users/ismaelfaro/.env/pyai/lib/python3.12/site-packages (from qiskit_addon_sqd) (0.6.2)
# Requirement already satisfied: jaxlib>=0.4.30 in /Users/ismaelfaro/.env/pyai/lib/python3.12/site-packages (from qiskit_addon_sqd) (0.6.2)
# Requirement already satisfied: ml_dtypes>=0.5.0 in /Users/ismaelfaro/.env/pyai/lib/python3.12/site-packages (from jax>=0.4.30->qiskit_addon_sqd) (0.5.1)
# Requirement already satisfied: rustworkx>=0.15.0 in /Users/ismaelfaro/.env/pyai/lib/python3.12/site-packages (from qiskit>=1.3->ffsim) (0.16.0)
# Requirement already satisfied: dill>=0.3 in /Users/ismaelfaro/.env/pyai/lib/python3.12/site-packages (from qiskit>=1.3->ffsim) (0.4.0)
# Requirement already satisfied: stevedore>=3.0.0 in /Users/ismaelfaro/.env/pyai/lib/python3.12/site-packages (from qiskit>=1.3->ffsim) (5.4.1)
# Requirement already satisfied: pbr>=2.0.0 in /Users/ismaelfaro/.env/pyai/lib/python3.12/site-packages (from stevedore>=3.0.0->qiskit>=1.3->ffsim) (6.1.1)
# Downloading joblib-1.5.1-py3-none-any.whl (307 kB)
# Installing collected packages: joblib
# Successfully installed joblib-1.5.1
#
# [notice] A new release of pip is available: 24.3.1 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip

# %%
## STEP 1 : Mapping the problem

import rustworkx as rx
import numpy as np

n = 5

graph = rx.PyGraph()
graph.add_nodes_from(np.arange(0, n, 1))
edge_list = [
    (0, 1, 1.0),
    (0, 2, 1.0),
    (0, 4, 1.0),
    (1, 2, 1.0),
    (2, 3, 1.0),
    (3, 4, 1.0),
]
graph.add_edges_from(edge_list)

from qiskit.quantum_info import SparsePauliOp


def build_max_cut_paulis(graph: rx.PyGraph) -> list[tuple[str, float]]:
    """Convert the graph to Pauli list.

    This function does the inverse of `build_max_cut_graph`
    """
    pauli_list = []
    for edge in list(graph.edge_list()):
        paulis = ["I"] * len(graph)
        paulis[edge[0]], paulis[edge[1]] = "Z", "Z"

        weight = graph.get_edge_data(edge[0], edge[1])

        pauli_list.append(("".join(paulis)[::-1], weight))

    return pauli_list


max_cut_paulis = build_max_cut_paulis(graph)

cost_hamiltonian = SparsePauliOp.from_list(max_cut_paulis)
print("Cost Function Hamiltonian:", cost_hamiltonian)

from qiskit.circuit.library import QAOAAnsatz

circuit = QAOAAnsatz(cost_operator=cost_hamiltonian, reps=2)
circuit.measure_all()
# Out:
# Cost Function Hamiltonian: SparsePauliOp(['IIIZZ', 'IIZIZ', 'ZIIIZ', 'IIZZI', 'IZZII', 'ZZIII'],
#               coeffs=[1.+0.j, 1.+0.j, 1.+0.j, 1.+0.j, 1.+0.j, 1.+0.j])

# %%
circuit

# %%
## STEP 2 : Optimize Circuit

from qiskit_ibm_runtime import QiskitRuntimeService
from qiskit.transpiler.preset_passmanagers import generate_preset_pass_manager

service = QiskitRuntimeService()

backend = service.backend("ibm_sherbrooke")

# QiskitRuntimeService.save_account(channel="ibm_quantum", token="<MY_IBM_QUANTUM_TOKEN>", overwrite=True, set_as_default=True)
# service = QiskitRuntimeService(channel="ibm_quantum")
# backend = service.least_busy(min_num_qubits=127)
# print(backend)

# Create pass manager for transpilation
pm = generate_preset_pass_manager(optimization_level=3, backend=backend)

candidate_circuit = pm.run(circuit)

# %%
## STEP 3 : Execute

initial_gamma = np.pi
initial_beta = np.pi / 2
init_params = [initial_gamma, initial_beta, initial_gamma, initial_beta]


def cost_func_estimator(params, ansatz, hamiltonian, estimator):

    # transform the observable defined on virtual qubits to
    # an observable defined on all physical qubits
    isa_hamiltonian = hamiltonian.apply_layout(ansatz.layout)

    pub = (ansatz, isa_hamiltonian, params)
    job = estimator.run([pub])

    results = job.result()[0]
    cost = results.data.evs

    objective_func_vals.append(cost)

    return cost


from qiskit_ibm_runtime import Session, EstimatorV2 as Estimator
from scipy.optimize import minimize

objective_func_vals = []  # Global variable
# with Session(backend=backend) as session:
    # If using qiskit-ibm-runtime<0.24.0, change `mode=` to `session=`
estimator = Estimator(mode=backend)
estimator.options.default_shots = 1000

# Set simple error suppression/mitigation options
estimator.options.dynamical_decoupling.enable = True
estimator.options.dynamical_decoupling.sequence_type = "XY4"
estimator.options.twirling.enable_gates = True
estimator.options.twirling.num_randomizations = "auto"

result = minimize(
    cost_func_estimator,
    init_params,
    args=(candidate_circuit, cost_hamiltonian, estimator),
    method="COBYLA",
    tol=1e-2,
)
print(result)

optimized_circuit = candidate_circuit.assign_parameters(result.x)

from qiskit_ibm_runtime import SamplerV2 as Sampler

# If using qiskit-ibm-runtime<0.24.0, change `mode=` to `backend=`
sampler = Sampler(mode=backend)
sampler.options.default_shots = 10000

# Set simple error suppression/mitigation options
sampler.options.dynamical_decoupling.enable = True
sampler.options.dynamical_decoupling.sequence_type = "XY4"
sampler.options.twirling.enable_gates = True
sampler.options.twirling.num_randomizations = "auto"

pub = (optimized_circuit,)
job = sampler.run([pub], shots=int(1e4))
counts_int = job.result()[0].data.meas.get_int_counts()
counts_bin = job.result()[0].data.meas.get_counts()
shots = sum(counts_int.values())
final_distribution_int = {key: val / shots for key, val in counts_int.items()}
final_distribution_bin = {key: val / shots for key, val in counts_bin.items()}
print(final_distribution_int)
# Out:
# ---------------------------------------------------------------------------
# RuntimeInvalidStateError                  Traceback (most recent call last)
# Cell In[12], line 40
#      37 estimator.options.twirling.enable_gates = True
#      38 estimator.options.twirling.num_randomizations = "auto"
# ---> 40 result = minimize(
#      41     cost_func_estimator,
#      42     init_params,
#      43     args=(candidate_circuit, cost_hamiltonian, estimator),
#      44     method="COBYLA",
#      45     tol=1e-2,
#      46 )
#      47 print(result)
#      49 optimized_circuit = candidate_circuit.assign_parameters(result.x)
#
# File ~/.env/pyai/lib/python3.12/site-packages/scipy/optimize/_minimize.py:791, in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     788     res = _minimize_tnc(fun, x0, args, jac, bounds, callback=callback,
#     789                         **options)
#     790 elif meth == 'cobyla':
# --> 791     res = _minimize_cobyla(fun, x0, args, constraints, callback=callback,
#     792                            bounds=bounds, **options)
#     793 elif meth == 'cobyqa':
#     794     res = _minimize_cobyqa(fun, x0, args, bounds, constraints, callback,
#     795                            **options)
#
# File ~/.env/pyai/lib/python3.12/site-packages/scipy/optimize/_cobyla_py.py:278, in _minimize_cobyla(fun, x0, args, constraints, rhobeg, tol, maxiter, disp, catol, f_target, callback, bounds, **unknown_options)
#     268 ctol = catol if catol is not None else np.sqrt(np.finfo(float).eps)
#     269 options = {
#     270     'rhobeg': rhobeg,
#     271     'rhoend': rhoend,
#    (...)    275     'ftarget': f_target,
#     276 }
# --> 278 result = minimize(sf.fun, x0, method='cobyla', bounds=bounds,
#     279                   constraints=constraints, callback=wrapped_callback,
#     280                   options=options)
#     283 if result.cstrv > ctol:
#     284     success = False
#
# File ~/.env/pyai/lib/python3.12/site-packages/scipy/_lib/pyprima/__init__.py:191, in minimize(fun, x0, args, method, bounds, constraints, callback, options)
#     188     options['maxfun'] = options['maxfev']
#     189     del options['maxfev']
# --> 191 result = cobyla(
#     192     calcfc,
#     193     len(nlconstr0),
#     194     x0,
#     195     A_ineq,
#     196     b_ineq,
#     197     A_eq,
#     198     b_eq,
#     199     lb,
#     200     ub,
#     201     f0=f0,
#     202     nlconstr0=nlconstr0,
#     203     callback=callback,
#     204     **options
#     205 )
#     207 if any(_fixed_idx):
#     208     newx = np.zeros(lenx0)
#
# File ~/.env/pyai/lib/python3.12/site-packages/scipy/_lib/pyprima/cobyla/cobyla.py:461, in cobyla(calcfc, m_nlcon, x, Aineq, bineq, Aeq, beq, xl, xu, f0, nlconstr0, rhobeg, rhoend, ftarget, ctol, cweight, maxfun, iprint, eta1, eta2, gamma1, gamma2, maxhist, maxfilt, callback)
#     417 (
#     418     iprint,
#     419     maxfun,
#    (...)    450     is_constrained=(mmm > 0),
#     451 )
#     453 # Further revise MAXHIST according to MAXHISTMEM, and allocate memory for the history.
#     454 # In MATLAB/Python/Julia/R implementation, we should simply set MAXHIST = MAXFUN and initialize
#     455 # CHIST = NaN(1, MAXFUN), CONHIST = NaN(M, MAXFUN), FHIST = NaN(1, MAXFUN), XHIST = NaN(N, MAXFUN)
#    (...)    459
#     460 # call cobylb, which performs the real calculations
# --> 461 x, f, constr, cstrv, nf, xhist, fhist, chist, conhist, info = cobylb(
#     462     calcfc,
#     463     iprint,
#     464     maxfilt,
#     465     maxfun,
#     466     amat,
#     467     bvec,
#     468     ctol,
#     469     cweight,
#     470     eta1,
#     471     eta2,
#     472     ftarget,
#     473     gamma1,
#     474     gamma2,
#     475     rhobeg,
#     476     rhoend,
#     477     constr,
#     478     f,
#     479     x,
#     480     maxhist,
#     481     callback
#     482 )
#     484 return COBYLAResult(x, f, constr, cstrv, nf, xhist, fhist, chist, conhist, info)
#
# File ~/.env/pyai/lib/python3.12/site-packages/scipy/_lib/pyprima/cobyla/cobylb.py:478, in cobylb(calcfc, iprint, maxfilt, maxfun, amat, bvec, ctol, cweight, eta1, eta2, ftarget, gamma1, gamma2, rhobeg, rhoend, constr, f, x, maxhist, callback)
#     474     cstrv = cval[j]
#     475 else:
#     476     # Evaluate the objective and constraints at X, taking care of possible
#     477     # inf/nan values.
# --> 478     f, constr = evaluate(calcfc, x, m_nlcon, amat, bvec)
#     479     cstrv = np.max(np.append(0, constr))
#     480     nf += 1
#
# File ~/.env/pyai/lib/python3.12/site-packages/scipy/_lib/pyprima/common/evaluate.py:80, in evaluate(calcfc, x, m_nlcon, amat, bvec)
#      78     constr = np.ones(m_nlcon) * f
#      79 else:
# ---> 80     f, constr[m_lcon:] = calcfc(moderatex(x))
#      82     # Moderated extreme barrier: replace NaN/huge objective or constraint values
#      83     # with a large but finite value. This is naive, and better approaches surely
#      84     # exist.
#      85     f = moderatef(f)
#
# File ~/.env/pyai/lib/python3.12/site-packages/scipy/_lib/pyprima/__init__.py:178, in minimize.<locals>.calcfc(x)
#     177 def calcfc(x):
# --> 178     f = fun(x, *args)
#     179     constr = np.zeros(0)
#     180     return f, constr
#
# File ~/.env/pyai/lib/python3.12/site-packages/scipy/optimize/_differentiable_functions.py:385, in ScalarFunction.fun(self, x)
#     383 if not np.array_equal(x, self.x):
#     384     self._update_x(x)
# --> 385 self._update_fun()
#     386 return self.f
#
# File ~/.env/pyai/lib/python3.12/site-packages/scipy/optimize/_differentiable_functions.py:353, in ScalarFunction._update_fun(self)
#     351 def _update_fun(self):
#     352     if not self.f_updated:
# --> 353         fx = self._wrapped_fun(self.x)
#     354         self._nfev += 1
#     355         if fx < self._lowest_f:
#
# File ~/.env/pyai/lib/python3.12/site-packages/scipy/_lib/_util.py:583, in _ScalarFunctionWrapper.__call__(self, x)
#     580 def __call__(self, x):
#     581     # Send a copy because the user may overwrite it.
#     582     # The user of this class might want `x` to remain unchanged.
# --> 583     fx = self.f(np.copy(x), *self.args)
#     584     self.nfev += 1
#     586     # Make sure the function returns a true scalar
#
# Cell In[12], line 17, in cost_func_estimator(params, ansatz, hamiltonian, estimator)
#      14 pub = (ansatz, isa_hamiltonian, params)
#      15 job = estimator.run([pub])
# ---> 17 results = job.result()[0]
#      18 cost = results.data.evs
#      20 objective_func_vals.append(cost)
#
# File ~/.env/pyai/lib/python3.12/site-packages/qiskit_ibm_runtime/runtime_job_v2.py:140, in RuntimeJobV2.result(self, timeout, decoder)
#     138     raise RuntimeJobFailureError(f"Unable to retrieve job result. {error_message}")
#     139 if self._status == "CANCELLED":
# --> 140     raise RuntimeInvalidStateError(
#     141         "Unable to retrieve result for job {}. " "Job was cancelled.".format(self.job_id())
#     142     )
#     144 result_raw = self._api_client.job_results(job_id=self.job_id())
#     146 return _decoder.decode(result_raw) if result_raw else None
#
# RuntimeInvalidStateError: 'Unable to retrieve result for job d1e6l2a576rs73cm7dug. Job was cancelled.'

# %%
# STEP 4 : Post-process


def to_bitstring(integer, num_bits):
    result = np.binary_repr(integer, width=num_bits)
    return [int(digit) for digit in result]


keys = list(final_distribution_int.keys())
values = list(final_distribution_int.values())
most_likely = keys[np.argmax(np.abs(values))]
most_likely_bitstring = to_bitstring(most_likely, len(graph))
most_likely_bitstring.reverse()

print("Result bitstring:", most_likely_bitstring)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 9
#       5     result = np.binary_repr(integer, width=num_bits)
#       6     return [int(digit) for digit in result]
# ----> 9 keys = list(final_distribution_int.keys())
#      10 values = list(final_distribution_int.values())
#      11 most_likely = keys[np.argmax(np.abs(values))]
#
# NameError: name 'final_distribution_int' is not defined

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 counts_int = job.result()[0].data.meas.get_int_counts()
#       2 counts_bin = job.result()[0].data.meas.get_counts()
#       3 shots = sum(counts_int.values())
#
# NameError: name 'job' is not defined
