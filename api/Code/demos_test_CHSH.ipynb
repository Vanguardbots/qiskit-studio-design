# %%
# !pip install pyscf ffsim qiskit_addon_sqd joblib
# Out:
# Requirement already satisfied: pyscf in /Users/ismaelfaro/.env/pyai/lib/python3.12/site-packages (2.9.0)
# Requirement already satisfied: ffsim in /Users/ismaelfaro/.env/pyai/lib/python3.12/site-packages (0.0.57)
# Requirement already satisfied: qiskit_addon_sqd in /Users/ismaelfaro/.env/pyai/lib/python3.12/site-packages (0.11.0)
# Collecting joblib
#   Downloading joblib-1.5.1-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: numpy!=1.16,!=1.17,>=1.13 in /Users/ismaelfaro/.env/pyai/lib/python3.12/site-packages (from pyscf) (2.3.1)
# Requirement already satisfied: scipy>=1.6.0 in /Users/ismaelfaro/.env/pyai/lib/python3.12/site-packages (from pyscf) (1.16.0)
# Requirement already satisfied: h5py>=2.7 in /Users/ismaelfaro/.env/pyai/lib/python3.12/site-packages (from pyscf) (3.14.0)
# Requirement already satisfied: setuptools in /Users/ismaelfaro/.env/pyai/lib/python3.12/site-packages (from pyscf) (80.9.0)
# Requirement already satisfied: opt-einsum in /Users/ismaelfaro/.env/pyai/lib/python3.12/site-packages (from ffsim) (3.4.0)
# Requirement already satisfied: orjson in /Users/ismaelfaro/.env/pyai/lib/python3.12/site-packages (from ffsim) (3.10.18)
# Requirement already satisfied: qiskit>=1.3 in /Users/ismaelfaro/.env/pyai/lib/python3.12/site-packages (from ffsim) (2.1.0)
# Requirement already satisfied: typing-extensions in /Users/ismaelfaro/.env/pyai/lib/python3.12/site-packages (from ffsim) (4.14.0)
# Requirement already satisfied: jax>=0.4.30 in /Users/ismaelfaro/.env/pyai/lib/python3.12/site-packages (from qiskit_addon_sqd) (0.6.2)
# Requirement already satisfied: jaxlib>=0.4.30 in /Users/ismaelfaro/.env/pyai/lib/python3.12/site-packages (from qiskit_addon_sqd) (0.6.2)
# Requirement already satisfied: ml_dtypes>=0.5.0 in /Users/ismaelfaro/.env/pyai/lib/python3.12/site-packages (from jax>=0.4.30->qiskit_addon_sqd) (0.5.1)
# Requirement already satisfied: rustworkx>=0.15.0 in /Users/ismaelfaro/.env/pyai/lib/python3.12/site-packages (from qiskit>=1.3->ffsim) (0.16.0)
# Requirement already satisfied: dill>=0.3 in /Users/ismaelfaro/.env/pyai/lib/python3.12/site-packages (from qiskit>=1.3->ffsim) (0.4.0)
# Requirement already satisfied: stevedore>=3.0.0 in /Users/ismaelfaro/.env/pyai/lib/python3.12/site-packages (from qiskit>=1.3->ffsim) (5.4.1)
# Requirement already satisfied: pbr>=2.0.0 in /Users/ismaelfaro/.env/pyai/lib/python3.12/site-packages (from stevedore>=3.0.0->qiskit>=1.3->ffsim) (6.1.1)
# Downloading joblib-1.5.1-py3-none-any.whl (307 kB)
# Installing collected packages: joblib
# Successfully installed joblib-1.5.1
#
# [notice] A new release of pip is available: 24.3.1 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip

# %%
## STEP 1 : Mapping the problem

import numpy as np

# Qiskit imports
from qiskit import QuantumCircuit
from qiskit.circuit import Parameter
from qiskit.quantum_info import SparsePauliOp


theta = Parameter("$\\theta$")

chsh_circuit = QuantumCircuit(2)
chsh_circuit.h(0)
chsh_circuit.cx(0, 1)
chsh_circuit.ry(theta, 0)

number_of_phases = 21
phases = np.linspace(0, 2 * np.pi, number_of_phases)
# Phases need to be expressed as list of lists in order to work
individual_phases = [[ph] for ph in phases]

# <CHSH1> = <AB> - <Ab> + <aB> + <ab> -> <ZZ> - <ZX> + <XZ> + <XX>
observable1 = SparsePauliOp.from_list([("ZZ", 1), ("ZX", -1), ("XZ", 1), ("XX", 1)])

# <CHSH2> = <AB> + <Ab> - <aB> + <ab> -> <ZZ> + <ZX> - <XZ> + <XX>
observable2 = SparsePauliOp.from_list([("ZZ", 1), ("ZX", 1), ("XZ", -1), ("XX", 1)])

# %%
chsh_circuit

# %%
## STEP 2 : Optimize Circuit

from qiskit.transpiler.preset_passmanagers import generate_preset_pass_manager
from qiskit_ibm_runtime import QiskitRuntimeService

service = QiskitRuntimeService(channel="ibm_quantum")
backend = service.least_busy(operational=True, simulator=False, min_num_qubits=127)
print(backend.name)

target = backend.target
pm = generate_preset_pass_manager(target=target, optimization_level=3)

chsh_isa_circuit = pm.run(chsh_circuit)

isa_observable1 = observable1.apply_layout(layout=chsh_isa_circuit.layout)
isa_observable2 = observable2.apply_layout(layout=chsh_isa_circuit.layout)
# Out:
# ibm_torino

# %%
## STEP 3 : Execute

from qiskit_ibm_runtime import EstimatorV2 as Estimator

estimator = Estimator(mode=backend)

pub = (
    chsh_isa_circuit,  # ISA circuit
    [[isa_observable1], [isa_observable2]],  # ISA Observables
    individual_phases,  # Parameter values
)

job_result = estimator.run(pubs=[pub]).result()

# %%
## STEP 4 : Post-process

chsh1_est = job_result[0].data.evs[0]
chsh2_est = job_result[0].data.evs[1]

# %%
chsh1_est
# Out:
# array([ 1.88690213,  1.15498831,  0.33209073, -0.51860744, -1.33847223,
#        -2.07948443, -2.54097428, -2.75882985, -2.74619321, -2.42421179,
#        -1.91470272, -1.17520692, -0.38314273,  0.51961837,  1.3374613 ,
#         2.03146522,  2.5480508 ,  2.75124787,  2.74922601,  2.45049599,
#         1.89650597])
